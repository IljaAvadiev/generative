# %%
# !pip install -q diffusers accelerate transformers

# %%
import torch
from PIL import Image
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from diffusers.utils import export_to_video
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
pipe = DiffusionPipeline.from_pretrained("cerspense/zeroscope_v2_576w", torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload(gpu_id=0)
# Out:
# ...
# unet/diffusion_pytorch_model.safetensors not found
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# ...

# %%
prompt = "grass, shallow depth of field, cinematic, nature, close up, beautiful"
prompt = 'a cinematic shot of a fox in the rain. Ultra-realistic, HD. during golden-hour'
prompt = 'a cinematic shot of a wolf in the rain, ultra-realistic, HD, during golden hour'
prompt = 'Clown fish swimming in a coral reef, beautiful, 8k, perfect, award winning, national geographic'
prompt = 'Angler Fish in the deep sea, 8k, ultra realistic, highly detailed'
prompt = 'A sea creature in the deep sea, beautiful, 8k, ultra realistic, highly detailed'
prompt = 'A shark swimming in the sea, beautiful, 8k, ultra realistic, highly detailed, cinematic'

# %%
# beautiful animals
# wolf
prompt = 'a cinematic shot of a wolf in the rain, ultra-realistic, HD, during golden hour'
#arctic fox
prompt = 'a cinematic shot of an arctic fox surrounded by snow, ultra-realistic, HD, during golden hour'
# lion
prompt = 'a cinematic shot of a lion sleeping in the sun, closeup, depth of field, ultra-realistic, HD, during golden hour'
# panda
prompt = 'a cinematic shot of a panda eating bamboo, ultra-realistic, HD, during golden hour'
# antelope
prompt = 'a cinematic shot of an antelope in the grass, ultra-realistic, HD, during golden hour'
# camel
prompt = 'a cinematic shot of a camel walking in the desert with dunes in the background, ultra-realistic, HD, during golden hour'
# baboon
prompt = 'a cinematic shot of a baboon sitting in a tree looking at the camera, ultra-realistic, HD, during golden hour'
# rabbit
prompt = 'a cinematic shot of a white rabbit on a green grass, ultra-realistic, HD, during golden hour'

# %%
file_names = [
#    'wolf',
#   'arctic_fox',
#    'lion',
#    'panda',
#    'antelope',
#    'camel',
#    'baboon',
#    'rabbit',
    'cat',
#    'horse',
    'deer',
#    'hamster',
    'racoon',
#    'elephant',
    'fox',
 #   'bear',
    'alpaca',
 #   'leopard',
#    'frog',
#    'giraffe',
#    'zebra',
#   'polar_bear',
#    'squirrel'
]

prompts = [
#    'a cinematic shot of a wolf in the rain, ultra-realistic, HD, during golden hour',
#    'a cinematic shot of an arctic fox surrounded by snow, ultra-realistic, HD, during golden hour',
#    'a cinematic shot of a lion sleeping in the sun, closeup, depth of field, ultra-realistic, HD, during golden hour',
#    'a cinematic shot of a panda eating bamboo, ultra-realistic, HD, during golden hour',
#   'a cinematic shot of an antelope in the grass, ultra-realistic, HD, during golden hour',
#    'a cinematic shot of a camel walking in the desert with dunes in the background, ultra-realistic, HD, during golden hour',
#    'a cinematic shot of a baboon sitting in a tree looking at the camera, ultra-realistic, HD, during golden hour',
#    'a cinematic shot of a white rabbit on a green grass, ultra-realistic, HD, during golden hour',
    'a cinematic shot of an elegant cat, ultra-realistic, HD, during golden hour',
#    'a cinematic shot of a galloping horse, ultra-realistic, HD, during golden hour',
    'a cinematic shot of a deer eating grass, beautiful, 8k, perfect, award winning, national geographic',
#    'a cinematic shot of a hamster eating a nut, beautiful, 8k, perfect, award winning, national geographic',
    'a cinematic shot of a racoon walking on grass, beautiful, 8k, perfect, award winning, national geographic',
#    'a cinematic shot of an elephant walking in the savanna towards the camera, beautiful, 8k, perfect, award winning, national geographic',
    'a cinematic shot of a fox in the rain, beautiful, 8k, perfect, award winning, national geographic',
#    'a cinematic shot of a bear sitting in the grass, beautiful, 8k, perfect, award winning, national geographic',
    'a cinematic shot of an white and brown alpaca, beautiful, 8k, perfect, award winning, national geographic',
#    'a cinematic shot of a leopard hunting, beautiful, 8k, perfect, award winning, national geographic',
#    'a cinematic shot of a green frog, depth of field, beautiful, 8k, perfect, award winning, national geographic',
#    'a cinematic shot of a giraffe eating from a tree, beautiful, 8k, perfect, award winning, national geographic',
#    'a cinematic shot of two zebras in a savanna, beautiful, 8k, perfect, award winning, national geographic',
#    'a cinematic shot of a polar bear in the arctic, snowing, beautiful, 8k, perfect, award winning, national geographic',
#    'a cinematic shot of a squirrel sitting on a tree eating a nut, beautiful, 8k, perfect, award winning, national geographic',
]

negative_prompt = 'ugly, blurry, noisy, washed out, distorted'

# %%
num_images = 3
for i, name in enumerate(file_names):
    print(f'Working on file {name}')
    prompt = prompts[i]
    for img_num in range(num_images):
        video_frames = pipe(prompt, negative_prompt=negative_prompt, num_inference_steps=40, height=320, width=576, num_frames=24).frames
        video_path = export_to_video(video_frames, output_video_path=f'/kaggle/working/{name}_{img_num}.mp4')
# Out:
# Working on file cat
# ...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Working on file deer
# ...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Working on file racoon
# ...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Working on file fox
# ...
#   0%|          | 0/40 [00:00<?, ?it/s]
# Working on file alpaca
# ...
#   0%|          | 0/40 [00:00<?, ?it/s]
